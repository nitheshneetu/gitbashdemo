# %%
import matplotlib.pyplot as plt
x = [1,2,3]
y = [2,3,1]
plt.plot(x,y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('my first graph')
plt.show()

# %%
# Out:
# Text(0.5, 0, 'x-axis')

# %%
# Out:
# Text(0, 0.5, 'y-axis')
